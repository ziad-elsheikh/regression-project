# %% [markdown]
# ## predicting Livestock Growth Rates: A Custom Regression Analysis on Feed and Health Data

# %% [markdown]
# ### Library Imports and Data Loading

# %%
import pandas as pd

# %%
file_path = 'data/uncleaned data/Livestock_Data.csv'
df = pd.read_csv( file_path)
df.head(10)
# Out:
#    CalfID  Pen  Block Season_x Phenotype Growth Milk        MBW       ADG  \
# 0    2505    4   2304     Fall        HH      H    H  91.644394  1.487013
# 1    2505    4   2304     Fall        HH      H    H  91.644394  1.487013
# 2    2505    4   2304     Fall        HH      H    H  91.644394  1.487013
# 3    2505    4   2304     Fall        HH      H    H  91.644394  1.487013
# 4    2505    4   2304     Fall        HH      H    H  91.644394  1.487013
# 5    2510    3   2304     Fall        HH      H    H  94.577808  1.168831
# 6    2510    3   2304     Fall        HH      H    H  94.577808  1.168831
# 7    2510    3   2304     Fall        HH      H    H  94.577808  1.168831
# 8    2510    3   2304     Fall        HH      H    H  94.577808  1.168831
# 9    2510    3   2304     Fall        HH      H    H  94.577808  1.168831
#
#         ODMI  ...    MCP1   MIP1b     TNFa   VEGFa  BHV1  BHV1_Log BVDV1  \
# 0  14.125714  ...  439.25   62.07   163.38   48.05    <4         0    32
# ...

# %%
file_path = 'data/uncleaned data/Data_Dictionary_Livestock.csv'
dic = pd.read_csv( file_path)
pd.set_option('display.max_colwidth', None)
dic.head(10)
# Out:
#   Column_Name  \
# 0      CalfID
# 1         Pen
# 2       Block
# 3    Season_x
# 4    Season_y
# 5        Year
# 6         Day
# 7   Timepoint
# 8       DamID
# 9        Sire
#
#                                                                       Description
# 0                                   Unique identification number for each animal.
# 1                        The specific enclosure or pen where the calf was housed.
# 2                        Experimental grouping or block used in the study design.
# 3      The season during which performance data was recorded (Suffix from Merge).
# 4  The season during which blood/immunity samples were taken (Suffix from Merge).
# 5                                       The calendar year the data was collected.
# 6                                    The specific day of the experiment or trial.
# 7               Specific temporal point when the sample or measurement was taken.
# ...

# %% [markdown]
# ## Task 1: data preprocessing
